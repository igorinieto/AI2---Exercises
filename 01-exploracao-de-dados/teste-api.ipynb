# %% [markdown]
# ### Importando bibliotecas

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ### Fazendo requisição

# %%
key_api = "dNasVA8au2QMwiPVsZ5a5ag5DFpYVWq4sDUN7a4J"
num_paginas = 1
dados = []
for pagina in range(num_paginas):
    requisicao = requests.get(f'https://api.nasa.gov/neo/rest/v1/neo/browse?page={pagina}&api_key={key_api}')
    dados.append(json.loads(requisicao.text))

# %%
dados
# Out:
# [{'links': {'next': 'http://www.neowsapp.com/rest/v1/neo/browse?page=1&size=20&api_key=dNasVA8au2QMwiPVsZ5a5ag5DFpYVWq4sDUN7a4J',
#    'self': 'http://www.neowsapp.com/rest/v1/neo/browse?page=0&size=20&api_key=dNasVA8au2QMwiPVsZ5a5ag5DFpYVWq4sDUN7a4J'},
#   'page': {'size': 20,
#    'total_elements': 27939,
#    'total_pages': 1397,
#    'number': 0},
#   'near_earth_objects': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2000433?api_key=dNasVA8au2QMwiPVsZ5a5ag5DFpYVWq4sDUN7a4J'},
#     'id': '2000433',
#     'neo_reference_id': '2000433',
#     'name': '433 Eros (A898 PA)',
#     'name_limited': 'Eros',
#     'designation': '433',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2000433',
#     'absolute_magnitude_h': 10.43,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 21.8049440483,
#       'estimated_diameter_max': 48.7573371375},
#      'meters': {'estimated_diameter_min': 21804.9440482866,
# ...
